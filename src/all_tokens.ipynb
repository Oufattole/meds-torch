# %%
import numpy as np
import polars as pl
from MEDS_torch.all_is_tokens import (
    calculate_quantiles,
    calculate_time_intervals,
    create_code_tokens,
    generate_patient_timeline,
    load_data,
    preprocess_and_group_tokens,
)

data_path = "../scripts/trash/tutorial_6/test.parquet"
df = load_data(data_path)
print("Original DataFrame:")
print(df)

# %%
# Calculate quantiles
df = calculate_quantiles(df)
print("\nDataFrame after calculating quantiles:")
print(df)

# %%
# Create code tokens
df = create_code_tokens(df)
print("\nDataFrame after creating code tokens:")
print(df)

# %%
# Preprocess and group tokens
df = preprocess_and_group_tokens(df)
print("\nDataFrame after preprocessing and grouping tokens:")
print(df)

# %%
# Calculate time intervals
df = calculate_time_intervals(df)
print("\nDataFrame after calculating time intervals:")
print(df)

# %%
# Generate patient timeline
timeline_df = generate_patient_timeline(df)
print("\nDataFrame with generated patient timeline:")
print(timeline_df)
